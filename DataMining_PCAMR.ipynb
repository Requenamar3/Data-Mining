# %% [markdown]
# <a href="https://colab.research.google.com/github/Requenamar3/Data-Mining/blob/main/DataMining_PCAMR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/fenago/datasets/main/protein.csv"
food_data = pd.read_csv(url)

# %%
food_data.head()
# Out:
#           Country   RedMeat   WhiteMeat   Eggs   Milk   Fish   Cereals  \
# 0         Albania      10.1         1.4    0.5    8.9    0.2      42.3
# 1         Austria       8.9        14.0    4.3   19.9    2.1      28.0
# 2         Belgium      13.5         9.3    4.1   17.5    4.5      26.6
# 3        Bulgaria       7.8         6.0    1.6    8.3    1.2      56.7
# 4  Czechoslovakia       9.7        11.4    2.8   12.5    2.0      34.3
#
#     Starch   Nuts   Fr&Veg
# 0      0.6    5.5      1.7
# 1      3.6    1.3      4.3
# 2      5.7    2.1      4.0
# 3      1.1    3.7      4.2
# 4      5.0    1.1      4.0
